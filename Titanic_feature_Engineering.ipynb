# %% [markdown]
# ## Use case: Survival data for passengers of the Titanic

# %% [markdown]
# ### Importing important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from ydata_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder,OrdinalEncoder
import warnings
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
import pickle
from sklearn.pipeline import Pipeline
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
import sklearn
print(sklearn.__version__) # We will be using this version for creating the pipline.
# Out:
# 1.6.1

# %%
# !pip install --upgrade ipython
# Out:
# Requirement already satisfied: ipython in c:\users\om computers\appdata\roaming\python\python313\site-packages (9.4.0)
# Collecting ipython
#   Downloading ipython-9.10.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\om computers\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\om computers\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Downloading ipython-9.10.0-py3-none-any.whl (622 kB)
#    ---------------------------------------- 0.0/622.8 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/622.8 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 622.8/622.8 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 9.4.0
#     Uninstalling ipython-9.4.0:
#       Successfully uninstalled ipython-9.4.0
# Successfully installed ipython-8.30.0
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.10.0 which is incompatible.
# spyder-kernels 3.0.5 requires ipython!=8.17.1,<9,>=8.13.0; python_version > "3.8", but you have ipython 9.10.0 which is incompatible.

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\om computers\anaconda3\lib\site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\om computers\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\om computers\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\om computers\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\om computers\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\om computers\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\om computers\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\om computers\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\om computers\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\om computers\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\om computers\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\om computers\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om computers\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\om computers\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\om computers\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\om computers\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\om computers\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\om computers\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\om computers\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\om computers\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\om computers\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\om computers\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\om computers\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\om computers\appdata\roaming\python\python313\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\om computers\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\om computers\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\users\om computers\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\om computers\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\Om Computers\anaconda3\Lib\site-packages)

# %%
data = pd.read_csv("titanic.csv")  # loading dataset

# %% [markdown]
# # Basic Checks '

# %%
data.head()   # showing first 5 rows and columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()   # showing last 5 rows and columns
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.shape  # it showing
# Out:
# (418, 12)

# %%
# This all columns are not important that's why we are going to drop mentioned columns
data=data.drop(['Ticket','PassengerId','Name','Cabin'], axis=1)

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# # Checking for outliers '

# %%
# Select numerical columns
numerical_cols = data.select_dtypes(include=['int', 'float']).columns

# Create box plots for all numerical features
plt.figure(figsize=(12, 8))
data[numerical_cols].boxplot()
plt.xticks(rotation=45)
plt.title('Box plots for Numerical Features')
plt.ylabel('Value')
plt.xlabel('Feature')
plt.show()

# %% [markdown]
# ## What is an outliers ?

# %% [markdown]
# - An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.
# - In a sense, this definition leaves it up to the analyst (or a consensus process) to decide what will be considered abnormal.
# - An outlier is a single data point that goes far outside the average value of a group of statistics.
# - Outliers may be exceptions that stand outside individual samples of populations as well.
# - In a more general context, an outlier is an individual that is markedly different from the norm in some respect.

# %%
data.info()   # it showing information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Fare      417 non-null    float64
#  7   Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 26.3+ KB

# %%
data.describe()   # it showing statistics informations
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     0.363636    2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.481622    0.841838   14.181209    0.896760    0.981429   55.907576
# min      0.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   39.000000    1.000000    0.000000   31.500000
# max      1.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# # EDA '

# %%
profile=ProfileReport(data,title="EDA",explorative=False)

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                            | 0/8 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 33.75it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-03-01 09:00:03.860267&quot; name=date&gt;&lt;title&gt;EDA&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# # Correlation Matrix '

# %%
sns.heatmap(data.select_dtypes(include=['int', 'float']).corr())
# Out:
# <Axes: >

# %%
np.where(data.select_dtypes(include=['int', 'float']).corr()>0.9)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([0, 1, 2, 3, 4, 5]))

# %% [markdown]
# - A correlation matrix is a statistical technique used to evaluate the relationship between two variables in a data set.
# - The matrix is a table in which every cell contains a correlation coefficient, where 1 is considered a strong relationship between variables, 0 a neutral relationship and -1 a not strong relationship.
# - We can also set up our own threshold values based on the datasets.

# %% [markdown]
# # Data  PreProcessing '

# %% [markdown]
# - Data preprocessing is a process of preparing the raw data and making it suitable for a machine learning model.
# - It is the first and crucial step while creating a machine learning model.
# - When creating a machine learning project, it is not always a case that we come across the clean and formatted data.

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# ### These are continuous columns so we will use standard scaler. But we can also divide age by 100 and that can be the transformation for age. Trasformation on age is just to see how we can apply custom transformations without using pre built scikit-learn functions.

# %% [markdown]
# - Fare

# %%
data[['Age','Fare']]
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %% [markdown]
# # Survived :

# %%
data.Survived.value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %% [markdown]
# - We won't be do anything for this column.

# %% [markdown]
# # Using One Hot Encoder here '

# %% [markdown]
# ## Sex :

# %%
data.Sex.value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %% [markdown]
# - We will be using OHE for this column.

# %% [markdown]
# - One-hot encoding is the most widely used categorical encoding technique. It is suitable for nominal categorical variables, where the categories have no inherent order or relationship. The idea behind one-hot encoding is to represent each category as a binary vector. Here’s how it works:
#
# - For each category in a categorical column, a new binary column is created.
#
# - The binary column will have a value of 1 if the class is present, else it will be zero.

# %% [markdown]
# # SibSp

# %%
data.SibSp.value_counts()
# Out:
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %% [markdown]
#  - The values were already arranged ordinally so we don't have to do anything.

# %% [markdown]
# # Parch :

# %%
data.Parch.value_counts()
# Out:
# Parch
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: count, dtype: int64

# %% [markdown]
#  - The values were already arranged ordinally so we don't have to do anything.

# %% [markdown]
# # Using Label Encoder here '

# %% [markdown]
# ## Embarked :

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %% [markdown]
# - We will be using label encoder for this column.

# %% [markdown]
# - Label encoding is suitable for categorical features with only two distinct categories.
#
# - In this technique, each category is assigned a unique integer label. Categories are assigned integer values starting from 0.
#
# - For example, if you have an ordinal categorical feature “Size” with values “Small,” “Medium,” and “Large,” label encoding would convert it.

# %% [markdown]
# # Function transformer :

# %%
def divide_by_100(x):
    return (x/100)

# %% [markdown]
# - we can use FunctionTrasformer to use our own custom function for transformation.
# - So we will use this custom function whe we are defining the pipeline.
# - We can define our funtion transformer whenever we need that in our pipeline.

# %%
custom=FunctionTransformer(divide_by_100)

# %% [markdown]
# # Using Modified Label Encoder '

# %% [markdown]
# ## Column Transformer :

# %%
class ModifiedLabelEncoder(LabelEncoder):
    def fit_transform(self, y, *args, **kwargs):
        return super().fit_transform(y).reshape(-1, 1)

    def transform(self, y, *args, **kwargs):
        return super().transform(y).reshape(-1, 1)

# %% [markdown]
# - You use the ColumnTransformer to transform each column set separately and then you can use the pipeline for multiple transformations of the same columns.
# - Column Transformer is a scikit-learn class used to create and apply separate transformers for numerical and categorical data. - To create transformers we need to specify the transformer object and pass the list of transformations inside a tuple along with the column on which you want to apply the transformation.

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
# We are defining here each columns that which scaling techniques are used for which columns :


OHE_columns=['Sex']
standard_scaler=['Fare']
function_trasformer=['Age']
label_encoder=['Embarked']

# %% [markdown]
# # Steps of preprocesing for features:
# - **LabelEncoder for**    :  'Embarked'
# - **One hot encoder for** :  'Sex'
# - **Standard scaler for** :  'Fare'
# - **Function transformer**:  'Age'

# %%
passthrough=["Pclass", "SibSp", "Parch", "Survived"]

# %%
def same(x):
    return x

# %%
no_trans=FunctionTransformer(same)

# %% [markdown]
# # Defining the preprocessor :

# %%
preprocessor=ColumnTransformer([('OHE_columns',OneHotEncoder(),OHE_columns),
                                ('standard_scaler',StandardScaler(),standard_scaler),
                                ('custom',custom,function_trasformer),
                                ('Label_encoder',ModifiedLabelEncoder(),['Embarked']),
                                ('Pass_through',no_trans,passthrough)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OHE_columns', OneHotEncoder(), ['Sex']),
#                                 ('standard_scaler', StandardScaler(), ['Fare']),
#                                 ('custom',
#                                  FunctionTransformer(func=<function divide_by_100 at 0x000002C4D56920C0>),
#                                  ['Age']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['Embarked']),
#                                 ('Pass_through',
#                                  FunctionTransformer(func=<function same at 0x000002C4D5690CC0>),
#                                  ['Pclass', 'SibSp', 'Parch', 'Survived'])])

# %% [markdown]
# # Creating Pickle file '

# %%
file = open("Titanic.pkl","wb")

# %%
pickle.dump(preprocessor,file)

# %%
file.close()

# %%
file = open("Titanic.pkl","rb")

# %%
pre = pickle.load(file)

# %%
pre
# Out:
# ColumnTransformer(transformers=[('OHE_columns', OneHotEncoder(), ['Sex']),
#                                 ('standard_scaler', StandardScaler(), ['Fare']),
#                                 ('custom',
#                                  FunctionTransformer(func=<function divide_by_100 at 0x000001D60C3F1F80>),
#                                  ['Age']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['Embarked']),
#                                 ('Pass_through',
#                                  FunctionTransformer(func=<function same at 0x000001D60C3F3A60>),
#                                  ['Pclass', 'SibSp', 'Parch', 'Survived'])])
